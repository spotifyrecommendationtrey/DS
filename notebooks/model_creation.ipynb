# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from scipy.spatial import KDTree
import pickle

# %%
df = pd.read_csv('../data/merged_data.csv')

# %%
scaler = MinMaxScaler()

# %%
df.head()
# Out:
#   artist_name                track_id  \
# 0          YG  2RM4jf1Xa9zPgMGRDiht8O
# 1          YG  1tHDG53xJNGsItRA3vfVgs
# 2       R3HAB  6Wosx2euFPMT14UXiWudMy
# 3  Chris Cooq  3J2Jpw61sO7l6Hc7qdYV91
# 4  Chris Cooq  2jbYvQCyPgX3CdmAzeVeuS
#
#                                        track_name  acousticness  danceability  \
# 0  Big Bank feat. 2 Chainz, Big Sean, Nicki Minaj      0.005820         0.743
# 1                    BAND DRUM (feat. A$AP Rocky)      0.024400         0.846
# 2                                   Radio Silence      0.025000         0.603
# 3                                         Lactose      0.029400         0.800
# 4                             Same - Original mix      0.000035         0.783
#
#    duration_ms  energy  instrumentalness  key  liveness  loudness  mode  \
# 0       238373   0.339             0.000    1    0.0812    -7.678     1
# 1       214800   0.557             0.000    8    0.2860    -7.259     1
# ...

# %%
df['track_id'][69]
# Out:
# '3Rx1zM3nDFQzAOYg9Hd0D4'

# %%
X = df.drop(['artist_name', 'track_id', 'track_name', 'popularity'], axis=1)
scaler.fit_transform(X)
# Out:
# array([[0.00584337, 0.74598394, 0.04194358, ..., 0.81576347, 0.8       ,
#         0.118     ],
#        [0.02449799, 0.84939759, 0.03773924, ..., 0.63607925, 0.8       ,
#         0.371     ],
#        [0.0251004 , 0.60542169, 0.02420446, ..., 0.45989527, 0.8       ,
#         0.382     ],
#        ...,
#        [0.06425703, 0.34437751, 0.05737961, ..., 0.68491457, 0.8       ,
#         0.365     ],
#        [0.02931727, 0.3815261 , 0.07493985, ..., 0.50323422, 0.6       ,
#         0.105     ],
#        [0.10140562, 0.8373494 , 0.04229673, ..., 0.51976334, 0.8       ,
#         0.193     ]])

# %%
model = KDTree(X)

# %%
result = model.query(df[df['track_id'] == '3Rx1zM3nDFQzAOYg9Hd0D4'].drop(['artist_name', 'track_id', 'track_name', 'popularity'], axis=1), k=11)

# %%
df[df['track_id'] == '3Rx1zM3nDFQzAOYg9Hd0D4']
# Out:
#    artist_name                track_id         track_name  acousticness  \
# 69    Beatsole  3Rx1zM3nDFQzAOYg9Hd0D4  Shanti (ASOT 874)      0.000215
#
#     danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 69         0.435       277098   0.796             0.887    2     0.407
#
#     loudness  mode  speechiness    tempo  time_signature  valence  popularity
# 69   -12.252     1       0.0687  132.049               4    0.106          31

# %%
result[1][0][1:11]
# Out:
# array([111123, 126891,  50679,  44817, 101573, 116609,  42439,  87795,
#         65046,  25414])

# %%
# This is a custom song with the audio features values below
result = model.query([[0.01, 0.5, 200000, 0.5, 0.1, 1, 0.1, -5, 1, 0.5, 190, 4, 0.5]], k=11)

# %%
result[1][0][1:]
# Out:
# array([ 25082, 112758,  19512,  20139,  63320,  15809, 102203,  77858,
#         85571,  37241])

# %%
# See that the suggested IDs correspond to the IDs in the database
df.iloc[result[1][0][1:]]
# Out:
#                artist_name                track_id             track_name  \
# 25082             Mountkid  1gRYSODTGjfufMdyu4Z3OV             No Lullaby
# 112758            Illenium  20KW4L9nwQ5oP4IHHrbCeY  Sound of Where'd U Go
# 19512          Deep Divers  5hKWeX4AmRMCNNBKxrD2AF        Dessous la mere
# 20139                xKore  0NSIvT9r4OfHf1Iep3Msro              Get Ready
# 63320       Omega Firebird  3OxM4vdtc2ZGGY0RYEl1sj            The Kingdom
# 15809              T Model  1aTCeLCNbgKHVwXuYn6BUz        Sucker For Love
# 102203        Rosie Carney  1gfzgfcrmkn2yTWuVGhCgh             Bud (Rose)
# 77858   Михаил Шуфутинский  79IYu1KNWZd9zoz3isep2V            До свидания
# 85571                Kunfu  0v0bbPylwszLuDBZ6yDpTM            Here I Come
# 37241             Gera MXM  2IwpV2UAbLErksGyl6YGXz  Perdido Más No Muerto
#
#         acousticness  danceability  duration_ms  energy  instrumentalness  \
# 25082        0.17400         0.600       200000  0.9400          0.515000
# ...

# %%
pickle.dump(model, open('suggestion_model.pkl', 'wb'))
